# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Data/data.csv")

# %%
data.plot.scatter(x="train_loss", y="validation_loss", alpha=0.5)
# Out:
# <AxesSubplot:xlabel='train_loss', ylabel='validation_loss'>

# %%
test_data = data

# %%
test_data["train_validation_loss_ratio"] = (test_data["train_loss"]/test_data["validation_loss"])

# %%
test_data.head(5)
# Out:
#    epoch  train_loss  train_acc  validation_loss  validation_acc  \
# 0      1    6.989439   0.001150        80.856150        0.000000
# 1      2    6.814090   0.002807         6.786588        0.004883
# 2      3    6.516962   0.007390         6.511988        0.011719
# 3      4    6.149220   0.014932        10.393121        0.005859
# 4      5    5.769540   0.027580         5.938978        0.015625
#
#    train_validation_loss_ratio
# 0                     0.086443
# 1                     1.004052
# 2                     1.000764
# 3                     0.591663
# 4                     0.971470

# %%
data.head(5)
# Out:
#    epoch  train_loss  train_acc  validation_loss  validation_acc  \
# 0      1    6.989439   0.001150        80.856150        0.000000
# 1      2    6.814090   0.002807         6.786588        0.004883
# 2      3    6.516962   0.007390         6.511988        0.011719
# 3      4    6.149220   0.014932        10.393121        0.005859
# 4      5    5.769540   0.027580         5.938978        0.015625
#
#    train_validation_loss_ratio
# 0                     0.086443
# 1                     1.004052
# 2                     1.000764
# 3                     0.591663
# 4                     0.971470

# %%
data.rename(
    columns = {
        "train_loss" : "TrainLoss",
        "train_acc" : "TrainAcc"
    }
)
# Out:
#     epoch  TrainLoss  TrainAcc  validation_loss  validation_acc  \
# 0       1   6.989439  0.001150        80.856150        0.000000
# 1       2   6.814090  0.002807         6.786588        0.004883
# 2       3   6.516962  0.007390         6.511988        0.011719
# 3       4   6.149220  0.014932        10.393121        0.005859
# 4       5   5.769540  0.027580         5.938978        0.015625
# ..    ...        ...       ...              ...             ...
# 94     95   0.008084  0.999696         6.287661        0.227314
# 95     96   0.007909  0.999611         6.166366        0.241612
# 96     97   0.007696  0.999882         6.388889        0.229542
# 97     98   0.008200  0.999510         6.258015        0.235126
# 98     99   0.008014  0.999679         6.082789        0.238331
#
#     train_validation_loss_ratio
# 0                      0.086443
# 1                      1.004052
# 2                      1.000764
# 3                      0.591663
# ...
